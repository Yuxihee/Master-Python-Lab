# %%
#https://data.ecb.europa.eu/data/datasets/IRS/IRS.M.I9.L.L40.CI.0000.EUR.N.Z
#Compare IRS of Austria,Belgium and Croatia

df1 = ecbdata.get_series('IRS.M.AT.L.L40.CI.0000.EUR.N.Z', start='2010-01')
df2 = ecbdata.get_series('IRS.M.BE.L.L40.CI.0000.EUR.N.Z', start='2010-01')
df3 = ecbdata.get_series('IRS.M.HR.L.L40.CI.0000.EUR.N.Z', start='2010-01')

df1.TIME_PERIOD = pd.to_datetime(df1.TIME_PERIOD)
df2.TIME_PERIOD = pd.to_datetime(df2.TIME_PERIOD)
df3.TIME_PERIOD = pd.to_datetime(df3.TIME_PERIOD)
df1 = df1.set_index('TIME_PERIOD')
df2 = df2.set_index('TIME_PERIOD')
df3 = df3.set_index('TIME_PERIOD')
df1.OBS_VALUE.plot(label='Austria')
df2.OBS_VALUE.plot(label='Belgium')
df3.OBS_VALUE.plot(label='Croatia')
plt.legend()
plt.show()

# %%
#https://data.ecb.europa.eu/data/datasets/MIR/MIR.M.U2.B.L22.A.R.A.2250.EUR.N
#Compare MIR of Austria,Belgium and Croatia

df1 = ecbdata.get_series('MIR.M.AT.B.L22.A.R.A.2250.EUR.N', start='2010-01')
df2 = ecbdata.get_series('MIR.M.BE.B.L22.A.R.A.2250.EUR.N', start='2010-01')
df3 = ecbdata.get_series('MIR.M.HR.B.L22.A.R.A.2250.EUR.N', start='2010-01')


df1.TIME_PERIOD = pd.to_datetime(df1.TIME_PERIOD)
df2.TIME_PERIOD = pd.to_datetime(df2.TIME_PERIOD)
df3.TIME_PERIOD = pd.to_datetime(df3.TIME_PERIOD)
df1 = df1.set_index('TIME_PERIOD')
df2 = df2.set_index('TIME_PERIOD')
df3 = df3.set_index('TIME_PERIOD')

df1.OBS_VALUE.plot(label='Austria')
df2.OBS_VALUE.plot(label='Belgium')
df3.OBS_VALUE.plot(label='Croatia')
plt.legend()
plt.show()
